# %% [markdown]
# <a href="https://colab.research.google.com/github/Mhkhalifaa/test-1/blob/main/intro%20one%20.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
kjgfl

# %%
sldhv

# %% [markdown]
# llsdgvl

# %%
lksdhvlkds
